# %%
import _base_path
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold , train_test_split
from resources.data_io import save_data, save_mappings
from resources.spans import SpanCollection

# %% [markdown]
# # Settings:

# %%
K =        5   # Number of cross validation splits
SEED =     42  # Random seed
DATASET =  'incidents'
SAVE_DIR = f'{DATASET}/splits/'

# %% [markdown]
# # Load Data:

# %% [markdown]
# ## Load "incidents":

# %%
# load incidents:
data = pd.read_csv(f"{DATASET}/{DATASET}_final.csv", index_col=0)

# fill nan-values:
data['product'].fillna('', inplace=True)
data['product-raw'].fillna('', inplace=True)
data['product-category'].fillna('', inplace=True)

data['hazard'].fillna('', inplace=True)
data['hazard-raw'].fillna('', inplace=True)
data['hazard-category'].fillna('', inplace=True)

data['country'].fillna('na', inplace=True)
data['language'].fillna('na', inplace=True)

# parse spans:
for col in ['product-title', 'product-text', 'hazard-title', 'hazard-text', 'supplier-title', 'supplier-text']: 
    if col in data.columns: data[col] = [SpanCollection.parse(item) for item in data[col].fillna('')]
    else:                   data[col] = [SpanCollection()] * len(data)

print(f"N = {len(data):d}")
data.head(5)
# Out:
# N = 7548
#    year  month  day                                                url  \
# 0  2015      5   26  https://www.fda.gov/Safety/Recalls/ArchiveReca...
# 1  2022      5   25  https://www.fda.gov/safety/recalls-market-with...
# 2  2020      6    2  http://www.cfs.gov.hk/english/whatsnew/whatsne...
# 3  2022      7    5  http://www.cfs.gov.hk/english/whatsnew/whatsne...
# 4  2021      3   20  http://www.fsis.usda.gov/recalls-alerts/avanza...
#
#                                                title  \
# 0  2015 - House of Spices (India) Inc. Issues Ale...
# 1  Supplier J.M. Smucker Co.’s Jif Recall Prompts...
# 2  *(Updated on 2 June 2020) Not to consume a bat...
# 3  *(Updated on 5 July 2022) Not to consume smoke...
# 4  Avanza Pasta, LLC Recalls Beef and Poultry Pro...
#
#                                                 text  \
# 0   April 23, 2015 – Flushing, NY – House of Spic...
# 1  (Miami, FL – May 24, 2022) - J.M. Smucker Co.’...
# 2  *(Updated on 2 June 2020) Not to consume a bat...
# 3  *(Updated on 5 July 2022) Not to consume smoke...
# 4  0009-2021\n\n  \n  High\n\n    Produced Withou...
#
#                       product            product-raw  \
# 0                    apricots         dried apricots
# 1                     peanuts                peanuts
# 2  fruit and vegetable juices            apple juice
# 3      fish and fish products  chilled smoked salmon
# 4              pasta products         pasta products
#
#                product-category                              product-title  \
# 0         fruits and vegetables                                         ()
# 1  nuts, nut products and seeds                                         ()
# 2       non-alcoholic beverages                      (slice(52, 71, None))
# 3                       seafood                      (slice(41, 54, None))
# 4    other food product / mixed  (slice(7, 12, None), slice(43, 51, None))
#
#                                         product-text  \
# 0  (slice(108, 120, None), slice(442, 454, None),...
# 1  (slice(229, 242, None), slice(470, 483, None),...
# 2  (slice(52, 71, None), slice(222, 241, None), s...
# 3  (slice(41, 54, None), slice(256, 277, None), s...
# 4  (slice(271, 276, None), slice(307, 315, None),...
#
#                           hazard              hazard-raw hazard-category  \
# 0  sulphur dioxide and sulphites     undeclared sulphite       allergens
# 1                       pathogen              salmonella      biological
# 2                      mycotoxin                 patulin        chemical
# 3                       pathogen  listeria monocytogenes      biological
# 4                      smuggling       inspection issues           fraud
#
#             hazard-title                                        hazard-text  \
# 0   (slice(7, 34, None))  (slice(33, 51, None), slice(98, 100, None), sl...
# 1  (slice(47, 62, None))  (slice(1, 10, None), slice(123, 138, None), sl...
# 2                     ()  (slice(354, 366, None), slice(581, 593, None),...
# 3                     ()  (slice(177, 185, None), slice(203, 207, None),...
# 4   (slice(0, 17, None))  (slice(264, 281, None), slice(617, 634, None),...
#
#           supplier-title                                      supplier-text  \
# 0   (slice(7, 34, None))  (slice(33, 51, None), slice(98, 100, None), sl...
# 1  (slice(47, 62, None))  (slice(1, 10, None), slice(123, 138, None), sl...
# 2                     ()  (slice(354, 366, None), slice(581, 593, None),...
# 3                     ()  (slice(177, 185, None), slice(203, 207, None),...
# 4   (slice(0, 17, None))  (slice(264, 281, None), slice(617, 634, None),...
#
#   language country
# 0       en      us
# 1       en      us
# 2       en      hk
# 3       en      hk
# 4       en      us

# %% [markdown]
# # Vectorize labels:

# %%
unique_labels = {}

for column in ['product', 'hazard', 'product-category', 'hazard-category']:
    # extract and sort unique values:
    unique_labels[column] = np.unique(data[column].values)
    unique_labels[column].sort()

    # create label-to-integer mapping:
    label2index = {l:i for i,l in enumerate(unique_labels[column])}

    # replace strings with integers:
    data[column] = data[column].apply(lambda label: label2index[label])

# %% [markdown]
# save mappings:

# %%
os.makedirs(SAVE_DIR, exist_ok=True)

save_mappings(SAVE_DIR,
    unique_labels['product'],
    unique_labels['hazard'],
    unique_labels['product-category'],
    unique_labels['hazard-category']
)

# %% [markdown]
# # Create K-Fold splits

# %%
data.head(5)
# Out:
#    year  month  day                                                url  \
# 0  2015      5   26  https://www.fda.gov/Safety/Recalls/ArchiveReca...
# 1  2022      5   25  https://www.fda.gov/safety/recalls-market-with...
# 2  2020      6    2  http://www.cfs.gov.hk/english/whatsnew/whatsne...
# 3  2022      7    5  http://www.cfs.gov.hk/english/whatsnew/whatsne...
# 4  2021      3   20  http://www.fsis.usda.gov/recalls-alerts/avanza...
#
#                                                title  \
# 0  2015 - House of Spices (India) Inc. Issues Ale...
# 1  Supplier J.M. Smucker Co.’s Jif Recall Prompts...
# 2  *(Updated on 2 June 2020) Not to consume a bat...
# 3  *(Updated on 5 July 2022) Not to consume smoke...
# 4  Avanza Pasta, LLC Recalls Beef and Poultry Pro...
#
#                                                 text  product  \
# 0   April 23, 2015 – Flushing, NY – House of Spic...       15
# 1  (Miami, FL – May 24, 2022) - J.M. Smucker Co.’...      433
# 2  *(Updated on 2 June 2020) Not to consume a bat...      250
# 3  *(Updated on 5 July 2022) Not to consume smoke...      206
# 4  0009-2021\n\n  \n  High\n\n    Produced Withou...      426
#
#              product-raw  product-category  \
# 0         dried apricots                10
# 1                peanuts                16
# 2            apple juice                15
# 3  chilled smoked salmon                20
# 4         pasta products                17
#
#                                product-title  \
# 0                                         ()
# 1                                         ()
# 2                      (slice(52, 71, None))
# 3                      (slice(41, 54, None))
# 4  (slice(7, 12, None), slice(43, 51, None))
#
#                                         product-text  hazard  \
# 0  (slice(108, 120, None), slice(442, 454, None),...     101
# 1  (slice(229, 242, None), slice(470, 483, None),...      74
# 2  (slice(52, 71, None), slice(222, 241, None), s...      58
# 3  (slice(41, 54, None), slice(256, 277, None), s...      74
# 4  (slice(271, 276, None), slice(307, 315, None),...      91
#
#                hazard-raw  hazard-category           hazard-title  \
# 0     undeclared sulphite                0   (slice(7, 34, None))
# 1              salmonella                1  (slice(47, 62, None))
# 2                 patulin                2                     ()
# 3  listeria monocytogenes                1                     ()
# 4       inspection issues                6   (slice(0, 17, None))
#
#                                          hazard-text         supplier-title  \
# 0  (slice(33, 51, None), slice(98, 100, None), sl...   (slice(7, 34, None))
# 1  (slice(1, 10, None), slice(123, 138, None), sl...  (slice(47, 62, None))
# 2  (slice(354, 366, None), slice(581, 593, None),...                     ()
# 3  (slice(177, 185, None), slice(203, 207, None),...                     ()
# 4  (slice(264, 281, None), slice(617, 634, None),...   (slice(0, 17, None))
#
#                                        supplier-text language country
# 0  (slice(33, 51, None), slice(98, 100, None), sl...       en      us
# 1  (slice(1, 10, None), slice(123, 138, None), sl...       en      us
# 2  (slice(354, 366, None), slice(581, 593, None),...       en      hk
# 3  (slice(177, 185, None), slice(203, 207, None),...       en      hk
# 4  (slice(264, 281, None), slice(617, 634, None),...       en      us

# %%
def filter_by_support(rows, column, min_support):
    for i_label, label in enumerate(unique_labels[column]):
        mask = (data.loc[rows, column].values == i_label)

        if sum(mask) < min_support:
            rows = rows[~mask]
            print(f'{column.upper()}: dropped class "{label}" with n_samples = {sum(mask)} < {min_support:d}.')

    return rows

# %%
for label_fine, label_coarse, columns in [
        ('product', 'product-category', [col for col in data.columns if not col.startswith('hazard')]),
        ('hazard',  'hazard-category',  [col for col in data.columns if not col.startswith('product')])
    ]:

    # drop coarse labels with less than K samples:
    i_filtered = filter_by_support(data.index, label_coarse, K)

    # create K-fold splits:
    kf = StratifiedKFold(n_splits=K, shuffle=True, random_state=SEED)
    for split, (i_train, i_test) in enumerate(kf.split(i_filtered, data.loc[i_filtered, label_coarse].values)):
        i_train = filter_by_support(i_filtered[i_train], label_coarse, 2)
        i_test  = i_filtered[i_test]
        # split off validation set:
        i_train, i_valid = train_test_split(
            i_train,
            test_size=.1,
            stratify=data.loc[i_train, label_coarse].values,
            shuffle=True,
            random_state=SEED
        )

        # save mappings:
        save_data(SAVE_DIR , split, label_fine,
            data.loc[i_train, columns],
            data.loc[i_valid, columns],
            data.loc[i_test,  columns]
        )
