# %%
import numpy as np
import pandas as pd
from tqdm.autonotebook import tqdm

# %%
LABEL     = 'product'
CV_SPLITS = [0]#, 1, 2, 3, 4]
SHOTS     = 2

# %% [markdown]
# # Load prompts:

# %%
prompts = pd.read_csv(f'prompts_{LABEL}_{SHOTS:d}-shot.csv', index_col=0)
prompts.head()
# Out:
#    cv_split                     label  \
# 0         0       other types of meat
# 1         0  Not classified pork meat
# 2         0             prepared dish
# 3         0          ground beef meat
# 4         0            chicken breast
#
#                                           prompt_all  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                 prompt_conformal_35%  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                 prompt_conformal_40%  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                 prompt_conformal_50%  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                        prompt_max-10  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                         prompt_max-5  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                        prompt_sim-10  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                        prompt_sim-20  ...  \
# 0  Context start:\nWe are looking for food produc...  ...
# 1  Context start:\nWe are looking for food produc...  ...
# 2  Context start:\nWe are looking for food produc...  ...
# 3  Context start:\nWe are looking for food produc...  ...
# 4  Context start:\nWe are looking for food produc...  ...
#
#                      output_min_sim-20                     output_min_sim-5  \
# 0                        chilli powder   hot chilli and hot chilli products
# 1              frozen poultry products                        boneless beef
# 2                         sesame paste  precooked cooked beef meat products
# 3                        beef products                       beef trimmings
# 4  mechanically separated chicken meat                       chicken breast
#
#   output_raw_all output_raw_conformal_35% output_raw_conformal_50%  \
# 0            NaN                      NaN                      NaN
# 1            NaN                      NaN                      NaN
# 2            NaN                      NaN            beef products
# 3            NaN                      NaN              ground beef
# 4            NaN                      NaN           chicken breast
#
#   output_raw_max-10 output_raw_max-5 output_raw_sim-10 output_raw_sim-20  \
# 0               NaN              NaN               NaN               NaN
# 1               NaN              NaN               NaN               NaN
# 2               NaN              NaN               NaN               NaN
# 3               NaN              NaN               NaN               NaN
# 4               NaN              NaN               NaN               NaN
#
#   output_raw_sim-5
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# # Evaluate prompts:

# %%
row_mask = np.bitwise_or.reduce([prompts.cv_split.values == split for split in CV_SPLITS])
row_mask.sum()
# Out:
# 1510

# %%
columns = [col[7:] for col in prompts.columns if col.startswith('prompt_')]
columns
# Out:
# ['all',
#  'conformal_35%',
#  'conformal_40%',
#  'conformal_50%',
#  'max-10',
#  'max-5',
#  'sim-10',
#  'sim-20',
#  'sim-5']

# %% [markdown]
# conformal only:

# %%
for col in columns:
    results = []

    for prompt in tqdm(prompts.loc[row_mask, f'prompt_{col}'].values):
        # get unique classes:
        classes = np.unique([example.split(' -> ')[1] for example in prompt.split('\n')[2:-3]])

        # if more than one class -> drop:
        if len(classes) == 1: results.append(classes[0])
        else: results.append(None)

    # save "prediction":
    col_name = f'output_raw_{col}'

    if col_name not in prompts.columns:
        prompts[col_name] = [''] * len(prompts)

    prompts.loc[row_mask, col_name] = results

# %% [markdown]
# min performance:

# %%
for col in columns:
    results = []

    for prompt in tqdm(prompts.loc[row_mask, f'prompt_{col}'].values):
        # get unique classes:
        classes = np.unique([example.split(' -> ')[1] for example in prompt.split('\n')[2:-3]])

        # if more than one class -> predict random:
        if len(classes) > 0:    results.append(np.random.choice(classes))
        else:                   results.append(None)

    # save "prediction":
    col_name = f'output_min_{col}'

    if col_name not in prompts.columns:
        prompts[col_name] = [''] * len(prompts)

    prompts.loc[row_mask, col_name] = results

# %% [markdown]
# max performance:

# %%
for col in columns:
    results = []

    for label, prompt in tqdm(prompts.loc[row_mask, ['label', f'prompt_{col}']].values):
        # get unique classes:
        classes = np.unique([example.split(' -> ')[1] for example in prompt.split('\n')[2:-3]])

        # true class not in set -> predict random:
        if label in classes:    results.append(label)
        elif len(classes) > 0:  results.append(np.random.choice(classes))
        else:                   results.append(None)

    # save "prediction":
    col_name = f'output_max_{col}'

    if col_name not in prompts.columns:
        prompts[col_name] = [''] * len(prompts)

    prompts.loc[row_mask, col_name] = results

# %% [markdown]
# # Save results:

# %%
prompts.head()
# Out:
#    cv_split                     label  \
# 0         0       other types of meat
# 1         0  Not classified pork meat
# 2         0             prepared dish
# 3         0          ground beef meat
# 4         0            chicken breast
#
#                                           prompt_all  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                 prompt_conformal_35%  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                 prompt_conformal_40%  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                 prompt_conformal_50%  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                        prompt_max-10  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                         prompt_max-5  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                        prompt_sim-10  \
# 0  Context start:\nWe are looking for food produc...
# 1  Context start:\nWe are looking for food produc...
# 2  Context start:\nWe are looking for food produc...
# 3  Context start:\nWe are looking for food produc...
# 4  Context start:\nWe are looking for food produc...
#
#                                        prompt_sim-20  ...  \
# 0  Context start:\nWe are looking for food produc...  ...
# 1  Context start:\nWe are looking for food produc...  ...
# 2  Context start:\nWe are looking for food produc...  ...
# 3  Context start:\nWe are looking for food produc...  ...
# 4  Context start:\nWe are looking for food produc...  ...
#
#   output_raw_conformal_35% output_raw_conformal_50% output_raw_max-10  \
# 0                     None                     None              None
# 1                     None                     None              None
# 2                     None            beef products              None
# 3                     None              ground beef              None
# 4                     None           chicken breast              None
#
#   output_raw_max-5 output_raw_sim-10 output_raw_sim-20 output_raw_sim-5  \
# 0             None              None              None             None
# 1             None              None              None             None
# 2             None              None              None             None
# 3             None              None              None             None
# 4             None              None              None             None
#
#   output_raw_conformal_40%     output_min_conformal_40%  \
# 0                     None  thermal processed pork meat
# 1                     None                          jam
# 2                     None               instant coffee
# 3                     None                       cheese
# 4                     None       chicken based products
#
#               output_max_conformal_40%
# 0            ready to eat - cook meals
# 1          thermal processed pork meat
# 2  precooked cooked beef meat products
# 3                          ground beef
# 4                       chicken breast
#
# [5 rows x 38 columns]

# %%
prompts.to_csv(f'prompts_{LABEL}_{SHOTS:d}-shot.csv')
